# %%
# Dependencies
import requests
import pandas as pd
import pathlib

# %%
#Set file path

filepath=pathlib.Path("../../datasets/players.csv")

#Read csv file
player_data_df=pd.read_csv(filepath)

# %%
player_data_df.head(5)
# Out:
#    Player ID First Name Last Name Team  Jersey Position Category Position  \
# 0   20000441    Bradley      Beal  WAS     3.0                 G       SG
# 1   20000442       John      Wall  WAS     2.0                 G       PG
# 2   20000443       Otto    Porter  CHI    22.0                 F       SF
# 3   20000452    Garrett    Temple  BKN    17.0                 G       SG
# 4   20000453   Terrence      Ross  ORL    31.0                 G       SG
#
#    Height  Weight           Birth Date   Birth City     Birth State  \
# 0      75     207  1993-06-28T00:00:00    St. Louis        Missouri
# 1      76     210  1990-09-06T00:00:00      Raleigh  North Carolina
# 2      80     198  1993-06-03T00:00:00    St. Louis        Missouri
# 3      77     195  1986-05-08T00:00:00  Baton Rouge       Louisiana
# 4      78     206  1991-02-05T00:00:00     Portland          Oregon
#
#   Birth Country     College      Salary  \
# 0           NaN     Florida  27093019.0
# 1           NaN    Kentucky  38199000.0
# 2           NaN  Georgetown  27250575.0
# 3           NaN         LSU   4767000.0
# 4        Oregon  Washington  12500000.0
#
#                                            Photo Url  Experience
# 0  https://s3-us-west-2.amazonaws.com/static.fant...           6
# 1  https://s3-us-west-2.amazonaws.com/static.fant...           8
# 2  https://s3-us-west-2.amazonaws.com/static.fant...           5
# 3  https://s3-us-west-2.amazonaws.com/static.fant...           8
# 4  https://s3-us-west-2.amazonaws.com/static.fant...           6

# %%
player_data_df["Name"]=player_data_df["First Name"] + " " + player_data_df["Last Name"]

# %%
del player_data_df["Birth Country"]

# %%
player_data_df
# Out:
#      Player ID First Name Last Name Team  Jersey Position Category Position  \
# 0     20000441    Bradley      Beal  WAS     3.0                 G       SG
# 1     20000442       John      Wall  WAS     2.0                 G       PG
# 2     20000443       Otto    Porter  CHI    22.0                 F       SF
# 3     20000452    Garrett    Temple  BKN    17.0                 G       SG
# 4     20000453   Terrence      Ross  ORL    31.0                 G       SG
# ..         ...        ...       ...  ...     ...               ...      ...
# 505   20002491      Caleb    Martin  CHA    10.0                 G       PG
# 506   20002493    Terence     Davis  TOR     0.0                 F       PF
# 507   20002494     Mychal    Mulder   GS    12.0                 G       PG
# 508   20002495      Marko   Guduric  MEM    23.0                 G       PG
# 509   20002497       Matt    Mooney  CLE    31.0                 G       PG
#
#      Height  Weight           Birth Date   Birth City     Birth State  \
# 0        75     207  1993-06-28T00:00:00    St. Louis        Missouri
# 1        76     210  1990-09-06T00:00:00      Raleigh  North Carolina
# 2        80     198  1993-06-03T00:00:00    St. Louis        Missouri
# 3        77     195  1986-05-08T00:00:00  Baton Rouge       Louisiana
# 4        78     206  1991-02-05T00:00:00     Portland          Oregon
# ..      ...     ...                  ...          ...             ...
# 505      77     205                  NaN          NaN             NaN
# 506      76     201                  NaN          NaN             NaN
# 507      76     184                  NaN          NaN             NaN
# 508      78     201                  NaN          NaN             NaN
# 509      75     200                  NaN          NaN             NaN
#
#         College      Salary  \
# 0       Florida  27093019.0
# 1      Kentucky  38199000.0
# 2    Georgetown  27250575.0
# 3           LSU   4767000.0
# 4    Washington  12500000.0
# ..          ...         ...
# 505      Nevada    898310.0
# 506    Ole Miss    898310.0
# 507    Kentucky         NaN
# 508         NaN   2625000.0
# 509  Texas Tech         NaN
#
#                                              Photo Url  Experience  \
# 0    https://s3-us-west-2.amazonaws.com/static.fant...           6
# 1    https://s3-us-west-2.amazonaws.com/static.fant...           8
# 2    https://s3-us-west-2.amazonaws.com/static.fant...           5
# 3    https://s3-us-west-2.amazonaws.com/static.fant...           8
# 4    https://s3-us-west-2.amazonaws.com/static.fant...           6
# ..                                                 ...         ...
# 505  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 506  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 507  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 508  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 509  https://s3-us-west-2.amazonaws.com/static.fant...           0
#
#                Name
# 0      Bradley Beal
# 1         John Wall
# 2       Otto Porter
# 3    Garrett Temple
# 4     Terrence Ross
# ..              ...
# 505    Caleb Martin
# 506   Terence Davis
# 507   Mychal Mulder
# 508   Marko Guduric
# 509     Matt Mooney
#
# [510 rows x 17 columns]

# %%
#Set file path

filepath=pathlib.Path("../../datasets/injuries_2010-2020.csv")

#Read csv file
injuries_df=pd.read_csv(filepath)

# %%
injuries_df
# Out:
#              Date       Team              Relinquished  \
# 0      2010-10-03      Bulls             Carlos Boozer
# 1      2010-10-06    Pistons             Jonas Jerebko
# 2      2010-10-06    Pistons             Terrico White
# 3      2010-10-08    Blazers                Jeff Ayres
# 4      2010-10-08       Nets               Troy Murphy
# ...           ...        ...                       ...
# 11245  2020-03-06     Pacers           Malcolm Brogdon
# 11246  2020-03-06   Pelicans  Nickeil Alexander-Walker
# 11247  2020-03-06    Rockets               Eric Gordon
# 11248  2020-03-06       Suns             Deandre Ayton
# 11249  2020-03-07  Cavaliers                 Dean Wade
#
#                                                    Notes
# 0      fractured bone in right pinky finger (out inde...
# 1          torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out ind...
# 3              torn ACL in right knee (out indefinitely)
# 4                 strained lower back (out indefinitely)
# ...                                                  ...
# 11245            torn left quadriceps (out indefinitely)
# 11246           fractured right wrist (out indefinitely)
# 11247                              sore right knee (DTD)
# 11248                          sprained left ankle (DTD)
# 11249                         sprained right ankle (DTD)
#
# [11250 rows x 4 columns]

# %%
injuries_df["Name"]=injuries_df["Relinquished"]

# %%
injuries_df
# Out:
#              Date       Team  \
# 0      2010-10-03      Bulls
# 1      2010-10-06    Pistons
# 2      2010-10-06    Pistons
# 3      2010-10-08    Blazers
# 4      2010-10-08       Nets
# ...           ...        ...
# 11245  2020-03-06     Pacers
# 11246  2020-03-06   Pelicans
# 11247  2020-03-06    Rockets
# 11248  2020-03-06       Suns
# 11249  2020-03-07  Cavaliers
#
#                                                    Notes  \
# 0      fractured bone in right pinky finger (out inde...
# 1          torn right Achilles tendon (out indefinitely)
# 2      broken fifth metatarsal in right foot (out ind...
# 3              torn ACL in right knee (out indefinitely)
# 4                 strained lower back (out indefinitely)
# ...                                                  ...
# 11245            torn left quadriceps (out indefinitely)
# 11246           fractured right wrist (out indefinitely)
# 11247                              sore right knee (DTD)
# 11248                          sprained left ankle (DTD)
# 11249                         sprained right ankle (DTD)
#
#                            Name
# 0                 Carlos Boozer
# 1                 Jonas Jerebko
# 2                 Terrico White
# 3                    Jeff Ayres
# 4                   Troy Murphy
# ...                         ...
# 11245           Malcolm Brogdon
# 11246  Nickeil Alexander-Walker
# 11247               Eric Gordon
# 11248             Deandre Ayton
# 11249                 Dean Wade
#
# [11250 rows x 4 columns]

# %%
join_data=injuries_df.merge(player_data_df, on='Name', how='inner')

join_data
# Out:
#             Date     Team_x                        Notes              Name  \
# 0     2010-11-03      Hawks               turf toe (DNP)    Jamal Crawford
# 1     2012-04-02    Blazers      right knee injury (DNP)    Jamal Crawford
# 2     2012-04-23    Blazers  right knee tendinitis (DNP)    Jamal Crawford
# 3     2012-04-26    Blazers  right knee tendinitis (DNP)    Jamal Crawford
# 4     2013-01-04   Clippers         sore left foot (DNP)    Jamal Crawford
# ...          ...        ...                          ...               ...
# 3540  2020-02-29   Warriors   sprained right ankle (DTD)      Jordan Poole
# 3541  2020-02-29   Warriors   sprained right ankle (DTD)         Ky Bowman
# 3542  2020-03-01  Cavaliers    strained left groin (DTD)    Darius Garland
# 3543  2020-03-01    Pistons   sprained right ankle (DTD)        Thon Maker
# 3544  2020-03-06      Bulls    sore right Achilles (DTD)  Ryan Arcidiacono
#
#       Player ID First Name    Last Name Team_y  Jersey Position Category  \
# 0      20000666      Jamal     Crawford    BKN     1.0                 G
# 1      20000666      Jamal     Crawford    BKN     1.0                 G
# 2      20000666      Jamal     Crawford    BKN     1.0                 G
# 3      20000666      Jamal     Crawford    BKN     1.0                 G
# 4      20000666      Jamal     Crawford    BKN     1.0                 G
# ...         ...        ...          ...    ...     ...               ...
# 3540   20002300     Jordan        Poole     GS     3.0                 G
# 3541   20002415         Ky       Bowman     GS    12.0                 G
# 3542   20002270     Darius      Garland    CLE    10.0                 G
# 3543   20001667       Thon        Maker    DET     7.0                 C
# 3544   20001746       Ryan  Arcidiacono    CHI    51.0                 G
#
#      Position  Height  Weight           Birth Date    Birth City  \
# 0          SG      77     185  1980-03-20T00:00:00       Seattle
# 1          SG      77     185  1980-03-20T00:00:00       Seattle
# 2          SG      77     185  1980-03-20T00:00:00       Seattle
# 3          SG      77     185  1980-03-20T00:00:00       Seattle
# 4          SG      77     185  1980-03-20T00:00:00       Seattle
# ...       ...     ...     ...                  ...           ...
# 3540       PG      76     194                  NaN           NaN
# 3541       PG      73     187                  NaN           NaN
# 3542       PG      73     192                  NaN           NaN
# 3543        C      84     221  1997-02-25T00:00:00        Sydney
# 3544       PG      75     195  1994-03-26T00:00:00  Philadelphia
#
#        Birth State         College     Salary  \
# 0       Washington        Michigan        NaN
# 1       Washington        Michigan        NaN
# 2       Washington        Michigan        NaN
# 3       Washington        Michigan        NaN
# 4       Washington        Michigan        NaN
# ...            ...             ...        ...
# 3540           NaN        Michigan  1964760.0
# 3541           NaN  Boston College   350189.0
# 3542           NaN      Vanderbilt  6400920.0
# 3543     Australia             NaN  3569643.0
# 3544  Pennsylvania       Villanova  3000000.0
#
#                                               Photo Url  Experience
# 0     https://s3-us-west-2.amazonaws.com/static.fant...          18
# 1     https://s3-us-west-2.amazonaws.com/static.fant...          18
# 2     https://s3-us-west-2.amazonaws.com/static.fant...          18
# 3     https://s3-us-west-2.amazonaws.com/static.fant...          18
# 4     https://s3-us-west-2.amazonaws.com/static.fant...          18
# ...                                                 ...         ...
# 3540  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 3541  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 3542  https://s3-us-west-2.amazonaws.com/static.fant...           0
# 3543  https://s3-us-west-2.amazonaws.com/static.fant...           2
# 3544  https://s3-us-west-2.amazonaws.com/static.fant...           1
#
# [3545 rows x 20 columns]

# %%
join_data.to_csv("../../datasets/player_injury.csv",index=False)

# %%
injuries_df.groupby('Name').count()
# Out:
#                  Date  Team  Acquired  Relinquished  Notes
# Name
# A.J. Price         17    17         0            17     17
# Aaron Brooks        6     6         0             6      6
# Aaron Gordon       11    11         0            11     11
# Aaron Gray          5     5         0             5      5
# Abdel Nader         2     2         0             2      2
# ...               ...   ...       ...           ...    ...
# Zach LaVine         8     8         0             8      8
# Zach Randolph      20    20         0            20     20
# Zaza Pachulia      27    27         0            27     27
# Zhaire Smith        1     1         0             1      1
# Zion Williamson     3     3         0             3      3
#
# [916 rows x 5 columns]
