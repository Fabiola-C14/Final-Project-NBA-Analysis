# %%
# Dependencies
import requests
import pandas as pd
import pathlib

# %%
#Set file path

filepath=pathlib.Path("players.csv")

#Read csv file
player_data_df=pd.read_csv(filepath)

# %%
player_data_df.head(5)
# Out:
#    Player ID First Name Last Name Team  Jersey Position Category Position  \
# 0   20000441    Bradley      Beal  WAS     3.0                 G       SG
# 1   20000442       John      Wall  WAS     2.0                 G       PG
# 2   20000443       Otto    Porter  CHI    22.0                 F       SF
# 3   20000452    Garrett    Temple  BKN    17.0                 G       SG
# 4   20000453   Terrence      Ross  ORL    31.0                 G       SG
#
#    Height  Weight           Birth Date   Birth City     Birth State  \
# 0      75     207  1993-06-28T00:00:00    St. Louis        Missouri
# 1      76     210  1990-09-06T00:00:00      Raleigh  North Carolina
# 2      80     198  1993-06-03T00:00:00    St. Louis        Missouri
# 3      77     195  1986-05-08T00:00:00  Baton Rouge       Louisiana
# 4      78     206  1991-02-05T00:00:00     Portland          Oregon
#
#   Birth Country     College      Salary  \
# 0           NaN     Florida  27093019.0
# ...

# %%
player_data_df["Name"]=player_data_df["First Name"] + " " + player_data_df["Last Name"]

# %%
player_data_df
# Out:
#      Player ID First Name Last Name Team  Jersey Position Category Position  \
# 0     20000441    Bradley      Beal  WAS     3.0                 G       SG
# 1     20000442       John      Wall  WAS     2.0                 G       PG
# 2     20000443       Otto    Porter  CHI    22.0                 F       SF
# 3     20000452    Garrett    Temple  BKN    17.0                 G       SG
# 4     20000453   Terrence      Ross  ORL    31.0                 G       SG
# ..         ...        ...       ...  ...     ...               ...      ...
# 505   20002491      Caleb    Martin  CHA    10.0                 G       PG
# 506   20002493    Terence     Davis  TOR     0.0                 F       PF
# 507   20002494     Mychal    Mulder   GS    12.0                 G       PG
# 508   20002495      Marko   Guduric  MEM    23.0                 G       PG
# 509   20002497       Matt    Mooney  CLE    31.0                 G       PG
#
# ...

# %%
#Set file path

filepath=pathlib.Path("injuries_2010_2020.csv")

#Read csv file
injuries_df=pd.read_csv(filepath)

# %%
injuries_df
# Out:
#             Date       Team Acquired              Relinquished  \
# 0      10/3/2010      Bulls      NaN             Carlos Boozer
# 1      10/6/2010    Pistons      NaN             Jonas Jerebko
# 2      10/6/2010    Pistons      NaN             Terrico White
# 3      10/8/2010    Blazers      NaN                Jeff Ayres
# 4      10/8/2010       Nets      NaN               Troy Murphy
# ...          ...        ...      ...                       ...
# 11245   3/6/2020     Pacers      NaN           Malcolm Brogdon
# 11246   3/6/2020   Pelicans      NaN  Nickeil Alexander-Walker
# 11247   3/6/2020    Rockets      NaN               Eric Gordon
# 11248   3/6/2020       Suns      NaN             Deandre Ayton
# 11249   3/7/2020  Cavaliers      NaN                 Dean Wade
#
#                                                    Notes
# 0      fractured bone in right pinky finger (out inde...
# 1          torn right Achilles tendon (out indefinitely)
# ...

# %%
injuries_df["Name"]=injuries_df["Relinquished"]

# %%
injuries_df
# Out:
#             Date       Team Acquired              Relinquished  \
# 0      10/3/2010      Bulls      NaN             Carlos Boozer
# 1      10/6/2010    Pistons      NaN             Jonas Jerebko
# 2      10/6/2010    Pistons      NaN             Terrico White
# 3      10/8/2010    Blazers      NaN                Jeff Ayres
# 4      10/8/2010       Nets      NaN               Troy Murphy
# ...          ...        ...      ...                       ...
# 11245   3/6/2020     Pacers      NaN           Malcolm Brogdon
# 11246   3/6/2020   Pelicans      NaN  Nickeil Alexander-Walker
# 11247   3/6/2020    Rockets      NaN               Eric Gordon
# 11248   3/6/2020       Suns      NaN             Deandre Ayton
# 11249   3/7/2020  Cavaliers      NaN                 Dean Wade
#
#                                                    Notes  \
# 0      fractured bone in right pinky finger (out inde...
# 1          torn right Achilles tendon (out indefinitely)
# ...

# %%
join_data=injuries_df.merge(player_data_df, on='Name', how='inner')

join_data
# Out:
#            Date     Team_x Acquired      Relinquished  \
# 0     11/3/2010      Hawks      NaN    Jamal Crawford
# 1      4/2/2012    Blazers      NaN    Jamal Crawford
# 2     4/23/2012    Blazers      NaN    Jamal Crawford
# 3     4/26/2012    Blazers      NaN    Jamal Crawford
# 4      1/4/2013   Clippers      NaN    Jamal Crawford
# ...         ...        ...      ...               ...
# 3540  2/29/2020   Warriors      NaN      Jordan Poole
# 3541  2/29/2020   Warriors      NaN         Ky Bowman
# 3542   3/1/2020  Cavaliers      NaN    Darius Garland
# 3543   3/1/2020    Pistons      NaN        Thon Maker
# 3544   3/6/2020      Bulls      NaN  Ryan Arcidiacono
#
#                             Notes              Name  Player ID First Name  \
# 0                  turf toe (DNP)    Jamal Crawford   20000666      Jamal
# 1         right knee injury (DNP)    Jamal Crawford   20000666      Jamal
# 2     right knee tendinitis (DNP)    Jamal Crawford   20000666      Jamal
# ...

# %%
join_data.to_csv("player_injury.csv",index=False)
