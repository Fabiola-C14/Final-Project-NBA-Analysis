# %%
import json
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
# Read csv
df = pd.read_csv('../../datasets/ASG_train.csv') 
# all_stars = all_players.loc[all_players['Selected?'] == 1]
df.head(10)
# Out:
#    Year  Avg. Pace            PLAYER TEAM  Team Conference Rank  GP  Team GP  \
# 0  1996       90.1    Michael Jordan  CHI                     1  40       40
# 1  1996       90.1  Shaquille O'Neal  LAL                     3  40       41
# 2  1996       90.1  Latrell Sprewell  GSW                     7  39       39
# 3  1996       90.1       Karl Malone  UTA                     4  40       40
# 4  1996       90.1   Hakeem Olajuwon  HOU                     1  37       41
# 5  1996       90.1    Mitch Richmond  SAC                     8  40       40
# 6  1996       90.1         Glen Rice  CHH                     6  37       40
# 7  1996       90.1     Allen Iverson  PHI                    15  34       39
# 8  1996       90.1         Vin Baker  MIL                    10  36       39
# 9  1996       90.1       Gary Payton  SEA                     2  40       40
#
#     W   PTS   REB  ...  BLK  TOV   TS%  3PM  DEFWS  USG%   PIE  \
# 0  35  30.9   5.8  ...  0.5  1.7  56.4  1.2  0.004  33.6  19.8
# 1  28  26.2  13.2  ...  3.1  3.1  55.7  0.0  0.003  30.4  18.4
# 2  16  25.9   4.9  ...  0.8  4.0  57.1  2.2  0.001  28.2  14.5
# 3  27  25.8  10.8  ...  0.7  3.1  57.6  0.0  0.003  31.5  20.8
# 4  28  24.1   9.4  ...  2.2  3.7  54.8  0.1  0.003  32.2  16.3
# 5  16  24.1   3.9  ...  0.3  2.8  56.0  1.8  0.002  28.4  14.3
# 6  21  24.0   4.2  ...  0.4  2.2  57.8  2.5  0.002  25.4  11.3
# 7   7  22.8   4.5  ...  0.4  4.9  50.3  2.2  0.000  29.0  10.3
# 8  18  22.4  10.7  ...  1.4  3.6  56.2  0.2  0.003  26.9  14.2
# 9  29  22.2   4.4  ...  0.1  2.5  55.1  1.4  0.004  26.0  15.6
#
#    Prior ASG Appearances  AS Last Year?  Selected?
# 0                     10              1          1
# 1                      4              1          1
# 2                      2              0          1
# 3                      9              1          1
# 4                     11              1          1
# 5                      4              1          1
# 6                      1              1          1
# 7                      0              0          0
# 8                      2              1          1
# 9                      3              1          1
#
# [10 rows x 22 columns]

# %%
label_name = 'Selected?'
# Out:
# 'Selected?'

# %%
features = (all_players.drop(['Selected?', 'Year', 'Avg. Pace', 'PLAYER', 'TEAM', 'AS Last Year?'], axis=1).columns.values)

# %%
df_dummy = all_players.drop(['Selected?', 'Year', 'Avg. Pace', 'PLAYER', 'TEAM', 'AS Last Year?'], axis=1)

# %%
def generator_1(clf, features, labels,original_features, node_index=0,side=0):
  
    node = {}
    if clf.tree_.children_left[node_index] == -1:  # indicates leaf
        count_labels = zip(clf.tree_.value[node_index, 0], labels)
        node['name'] = ', '.join(('{} of {}'.format(int(count), label)
                                  for count, label in count_labels))
        node['size'] = sum( clf.tree_.value[node_index, 0]  )   
        node['side'] = 'left' if side == 'l' else 'right'                      
    else:

        count_labels = zip(clf.tree_.value[node_index, 0], labels)
        node['pred'] = ', '.join(('{} of {}'.format(int(count), label)
                                  for count, label in count_labels))
                                      
        node['side'] = 'left' if side == 'l' else 'right'                              
        feature = features[clf.tree_.feature[node_index]]
        threshold = clf.tree_.threshold[node_index]
        
        if ('_-_' in feature) and (feature not in original_features):
            node['name'] =  '{} = {}'.format(feature.split('_-_')[0], feature.split('_-_')[1] )
            node['type'] = 'categorical'
        else:
            node['name'] = '{} > {}'.format(feature, round(threshold,2) )
            node['type'] = 'numerical'
        
        left_index = clf.tree_.children_left[node_index]
        right_index = clf.tree_.children_right[node_index]
        
        node['size'] = sum (clf.tree_.value[node_index, 0])
        node['children'] = [generator_1(clf, features, labels, original_features, right_index,'r'),
                            generator_1(clf, features, labels, original_features, left_index,'l')]
                            
        
    return node

# %%
def generator_2(clf, features, labels,original_features, node_index=0,side=0,prev_index=0):

    node = {}
    if clf.tree_.children_left[node_index] == -1:  # indicates leaf
        count_labels = zip(clf.tree_.value[node_index, 0], labels)
        node['pred'] = ', '.join(('{} of {}'.format(int(count), label)
                                  for count, label in count_labels))
                                      
        node['side'] = 'left' if side == 'l' else 'right'                              
        feature = features[clf.tree_.feature[prev_index]]
        threshold = clf.tree_.threshold[prev_index]
        
            
        if node_index == 0:
            node["name"] = 'Root >'
        elif ('_-_' in feature) and (feature not in original_features):
            
            node['name'] =  '{} = {}'.format(feature.split('_-_')[0], feature.split('_-_')[1] ) if side == 'r' else '{} != {}'.format(feature.split('_-_')[0], feature.split('_-_')[1] )  
            node['type'] = 'categorical'
        else:
            node['name'] = '{} > {}'.format(feature, round(threshold,2) ) if side == 'r' else '{} <= {}'.format(feature, round(threshold,2) ) 
            node['type'] = 'numerical'
        
        left_index = clf.tree_.children_left[node_index]
        right_index = clf.tree_.children_right[node_index]
        
        node['size'] = sum (clf.tree_.value[node_index, 0])
           
    else:

        count_labels = zip(clf.tree_.value[node_index, 0], labels)
        node['pred'] = ', '.join(('{} of {}'.format(int(count), label)
                                  for count, label in count_labels))
                                      
        node['side'] = 'left' if side == 'l' else 'right'                              
        feature = features[clf.tree_.feature[prev_index]]
        threshold = clf.tree_.threshold[prev_index]
        
            
        if node_index == 0:
            node["name"] = 'Root >'
        elif ('_-_' in feature) and (feature not in original_features):
            
            node['name'] =  '{} = {}'.format(feature.split('_-_')[0], feature.split('_-_')[1] ) if side == 'r' else '{} != {}'.format(feature.split('_-_')[0], feature.split('_-_')[1] )  
            node['type'] = 'categorical'
        else:
            node['name'] = '{} > {}'.format(feature, round(threshold,2) ) if side == 'r' else '{} <= {}'.format(feature, round(threshold,2) ) 
            node['type'] = 'numerical'
        
        left_index = clf.tree_.children_left[node_index]
        right_index = clf.tree_.children_right[node_index]
        
        node['size'] = sum (clf.tree_.value[node_index, 0])
        node['children'] = [generator_2(clf, features, labels, original_features, right_index,'r',node_index),
                            generator_2(clf, features, labels, original_features, left_index,'l',node_index)]
                            
        
    return node

# %%
clf = DecisionTreeClassifier(max_depth=5)
clf.fit(df_dummy, df[label_name])

io=generator_1(clf, df_dummy.columns,np.unique(df[label_name]),features)

print(json.dumps(io, indent=4))

with open('structureC1.json', 'w') as outfile:
    json.dump(io, outfile, indent=4)
    
    
io=generator_2(clf, df_dummy.columns,np.unique(df[label_name]),features)

print(json.dumps(io, indent=4))

with open('structureC2.json', 'w') as outfile:
    json.dump(io, outfile, indent=4)
# Out:
# {
#     "pred": "9025 of 0, 570 of 1",
#     "side": "right",
#     "name": "PTS > 18.45",
#     "type": "numerical",
#     "size": 9595.0,
#     "children": [
#         {
#             "pred": "302 of 0, 420 of 1",
#             "side": "right",
#             "name": "PIE > 14.25",
#             "type": "numerical",
#             "size": 722.0,
#             "children": [
#                 {
#                     "pred": "61 of 0, 306 of 1",
#                     "side": "right",
#                     "name": "W > 19.5",
#                     "type": "numerical",
#                     "size": 367.0,
#                     "children": [
#                         {
#                             "pred": "18 of 0, 239 of 1",
#                             "side": "right",
#                             "name": "PTS > 22.05",
#                             "type": "numerical",
#                             "size": 257.0,
#                             "children": [
#                                 {
#                                     "pred": "1 of 0, 159 of 1",
#                                     "side": "right",
#                                     "name": "REB > 2.6",
#                                     "type": "numerical",
#                                     "size": 160.0,
#                                     "children": [
#                                         {
#                                             "name": "0 of 0, 159 of 1",
#                                             "size": 159.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "1 of 0, 0 of 1",
#                                             "size": 1.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "17 of 0, 80 of 1",
#                                     "side": "left",
#                                     "name": "W > 25.5",
#                                     "type": "numerical",
#                                     "size": 97.0,
#                                     "children": [
#                                         {
#                                             "name": "1 of 0, 52 of 1",
#                                             "size": 53.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "16 of 0, 28 of 1",
#                                             "size": 44.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "43 of 0, 67 of 1",
#                             "side": "left",
#                             "name": "PTS > 23.25",
#                             "type": "numerical",
#                             "size": 110.0,
#                             "children": [
#                                 {
#                                     "pred": "7 of 0, 42 of 1",
#                                     "side": "right",
#                                     "name": "USG% > 26.75",
#                                     "type": "numerical",
#                                     "size": 49.0,
#                                     "children": [
#                                         {
#                                             "name": "4 of 0, 41 of 1",
#                                             "size": 45.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "3 of 0, 1 of 1",
#                                             "size": 4.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "36 of 0, 25 of 1",
#                                     "side": "left",
#                                     "name": "DEFWS > 0.0",
#                                     "type": "numerical",
#                                     "size": 61.0,
#                                     "children": [
#                                         {
#                                             "name": "2 of 0, 10 of 1",
#                                             "size": 12.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "34 of 0, 15 of 1",
#                                             "size": 49.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "pred": "241 of 0, 114 of 1",
#                     "side": "left",
#                     "name": "Team Conference Rank > 6.5",
#                     "type": "numerical",
#                     "size": 355.0,
#                     "children": [
#                         {
#                             "pred": "193 of 0, 40 of 1",
#                             "side": "right",
#                             "name": "PTS > 21.55",
#                             "type": "numerical",
#                             "size": 233.0,
#                             "children": [
#                                 {
#                                     "pred": "38 of 0, 27 of 1",
#                                     "side": "right",
#                                     "name": "Prior ASG Appearances > 1.5",
#                                     "type": "numerical",
#                                     "size": 65.0,
#                                     "children": [
#                                         {
#                                             "name": "3 of 0, 12 of 1",
#                                             "size": 15.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "35 of 0, 15 of 1",
#                                             "size": 50.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "155 of 0, 13 of 1",
#                                     "side": "left",
#                                     "name": "AST > 8.65",
#                                     "type": "numerical",
#                                     "size": 168.0,
#                                     "children": [
#                                         {
#                                             "name": "3 of 0, 3 of 1",
#                                             "size": 6.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "152 of 0, 10 of 1",
#                                             "size": 162.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "48 of 0, 74 of 1",
#                             "side": "left",
#                             "name": "PIE > 11.5",
#                             "type": "numerical",
#                             "size": 122.0,
#                             "children": [
#                                 {
#                                     "pred": "28 of 0, 67 of 1",
#                                     "side": "right",
#                                     "name": "W > 13.5",
#                                     "type": "numerical",
#                                     "size": 95.0,
#                                     "children": [
#                                         {
#                                             "name": "21 of 0, 65 of 1",
#                                             "size": 86.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "7 of 0, 2 of 1",
#                                             "size": 9.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "20 of 0, 7 of 1",
#                                     "side": "left",
#                                     "name": "PTS > 20.55",
#                                     "type": "numerical",
#                                     "size": 27.0,
#                                     "children": [
#                                         {
#                                             "name": "2 of 0, 7 of 1",
#                                             "size": 9.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "18 of 0, 0 of 1",
#                                             "size": 18.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pred": "8723 of 0, 150 of 1",
#             "side": "left",
#             "name": "PIE > 12.95",
#             "type": "numerical",
#             "size": 8873.0,
#             "children": [
#                 {
#                     "pred": "559 of 0, 103 of 1",
#                     "side": "right",
#                     "name": "Prior ASG Appearances > 0.5",
#                     "type": "numerical",
#                     "size": 662.0,
#                     "children": [
#                         {
#                             "pred": "113 of 0, 74 of 1",
#                             "side": "right",
#                             "name": "PTS > 16.55",
#                             "type": "numerical",
#                             "size": 187.0,
#                             "children": [
#                                 {
#                                     "pred": "20 of 0, 33 of 1",
#                                     "side": "right",
#                                     "name": "Team Conference Rank > 7.5",
#                                     "type": "numerical",
#                                     "size": 53.0,
#                                     "children": [
#                                         {
#                                             "name": "11 of 0, 3 of 1",
#                                             "size": 14.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "9 of 0, 30 of 1",
#                                             "size": 39.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "93 of 0, 41 of 1",
#                                     "side": "left",
#                                     "name": "AST > 8.5",
#                                     "type": "numerical",
#                                     "size": 134.0,
#                                     "children": [
#                                         {
#                                             "name": "6 of 0, 13 of 1",
#                                             "size": 19.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "87 of 0, 28 of 1",
#                                             "size": 115.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "446 of 0, 29 of 1",
#                             "side": "left",
#                             "name": "W > 24.5",
#                             "type": "numerical",
#                             "size": 475.0,
#                             "children": [
#                                 {
#                                     "pred": "44 of 0, 17 of 1",
#                                     "side": "right",
#                                     "name": "PTS > 16.45",
#                                     "type": "numerical",
#                                     "size": 61.0,
#                                     "children": [
#                                         {
#                                             "name": "3 of 0, 7 of 1",
#                                             "size": 10.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "41 of 0, 10 of 1",
#                                             "size": 51.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "402 of 0, 12 of 1",
#                                     "side": "left",
#                                     "name": "DEFWS > 0.01",
#                                     "type": "numerical",
#                                     "size": 414.0,
#                                     "children": [
#                                         {
#                                             "name": "5 of 0, 4 of 1",
#                                             "size": 9.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "397 of 0, 8 of 1",
#                                             "size": 405.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "pred": "8164 of 0, 47 of 1",
#                     "side": "left",
#                     "name": "PTS > 16.05",
#                     "type": "numerical",
#                     "size": 8211.0,
#                     "children": [
#                         {
#                             "pred": "263 of 0, 24 of 1",
#                             "side": "right",
#                             "name": "DEFWS > 0.0",
#                             "type": "numerical",
#                             "size": 287.0,
#                             "children": [
#                                 {
#                                     "pred": "19 of 0, 12 of 1",
#                                     "side": "right",
#                                     "name": "PIE > 11.55",
#                                     "type": "numerical",
#                                     "size": 31.0,
#                                     "children": [
#                                         {
#                                             "name": "5 of 0, 12 of 1",
#                                             "size": 17.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "14 of 0, 0 of 1",
#                                             "size": 14.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "244 of 0, 12 of 1",
#                                     "side": "left",
#                                     "name": "STL > 2.3",
#                                     "type": "numerical",
#                                     "size": 256.0,
#                                     "children": [
#                                         {
#                                             "name": "1 of 0, 2 of 1",
#                                             "size": 3.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "243 of 0, 10 of 1",
#                                             "size": 253.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "7901 of 0, 23 of 1",
#                             "side": "left",
#                             "name": "TOV > 5.05",
#                             "type": "numerical",
#                             "size": 7924.0,
#                             "children": [
#                                 {
#                                     "name": "0 of 0, 1 of 1",
#                                     "size": 1.0,
#                                     "side": "right"
#                                 },
#                                 {
#                                     "pred": "7901 of 0, 22 of 1",
#                                     "side": "left",
#                                     "name": "Prior ASG Appearances > 8.5",
#                                     "type": "numerical",
#                                     "size": 7923.0,
#                                     "children": [
#                                         {
#                                             "name": "36 of 0, 5 of 1",
#                                             "size": 41.0,
#                                             "side": "right"
#                                         },
#                                         {
#                                             "name": "7865 of 0, 17 of 1",
#                                             "size": 7882.0,
#                                             "side": "left"
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
# {
#     "pred": "9025 of 0, 570 of 1",
#     "side": "right",
#     "name": "Root >",
#     "size": 9595.0,
#     "children": [
#         {
#             "pred": "302 of 0, 420 of 1",
#             "side": "right",
#             "name": "PTS > 18.45",
#             "type": "numerical",
#             "size": 722.0,
#             "children": [
#                 {
#                     "pred": "61 of 0, 306 of 1",
#                     "side": "right",
#                     "name": "PIE > 14.25",
#                     "type": "numerical",
#                     "size": 367.0,
#                     "children": [
#                         {
#                             "pred": "18 of 0, 239 of 1",
#                             "side": "right",
#                             "name": "W > 19.5",
#                             "type": "numerical",
#                             "size": 257.0,
#                             "children": [
#                                 {
#                                     "pred": "1 of 0, 159 of 1",
#                                     "side": "right",
#                                     "name": "PTS > 22.05",
#                                     "type": "numerical",
#                                     "size": 160.0,
#                                     "children": [
#                                         {
#                                             "pred": "0 of 0, 159 of 1",
#                                             "side": "right",
#                                             "name": "REB > 2.6",
#                                             "type": "numerical",
#                                             "size": 159.0
#                                         },
#                                         {
#                                             "pred": "1 of 0, 0 of 1",
#                                             "side": "left",
#                                             "name": "REB <= 2.6",
#                                             "type": "numerical",
#                                             "size": 1.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "17 of 0, 80 of 1",
#                                     "side": "left",
#                                     "name": "PTS <= 22.05",
#                                     "type": "numerical",
#                                     "size": 97.0,
#                                     "children": [
#                                         {
#                                             "pred": "1 of 0, 52 of 1",
#                                             "side": "right",
#                                             "name": "W > 25.5",
#                                             "type": "numerical",
#                                             "size": 53.0
#                                         },
#                                         {
#                                             "pred": "16 of 0, 28 of 1",
#                                             "side": "left",
#                                             "name": "W <= 25.5",
#                                             "type": "numerical",
#                                             "size": 44.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "43 of 0, 67 of 1",
#                             "side": "left",
#                             "name": "W <= 19.5",
#                             "type": "numerical",
#                             "size": 110.0,
#                             "children": [
#                                 {
#                                     "pred": "7 of 0, 42 of 1",
#                                     "side": "right",
#                                     "name": "PTS > 23.25",
#                                     "type": "numerical",
#                                     "size": 49.0,
#                                     "children": [
#                                         {
#                                             "pred": "4 of 0, 41 of 1",
#                                             "side": "right",
#                                             "name": "USG% > 26.75",
#                                             "type": "numerical",
#                                             "size": 45.0
#                                         },
#                                         {
#                                             "pred": "3 of 0, 1 of 1",
#                                             "side": "left",
#                                             "name": "USG% <= 26.75",
#                                             "type": "numerical",
#                                             "size": 4.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "36 of 0, 25 of 1",
#                                     "side": "left",
#                                     "name": "PTS <= 23.25",
#                                     "type": "numerical",
#                                     "size": 61.0,
#                                     "children": [
#                                         {
#                                             "pred": "2 of 0, 10 of 1",
#                                             "side": "right",
#                                             "name": "DEFWS > 0.0",
#                                             "type": "numerical",
#                                             "size": 12.0
#                                         },
#                                         {
#                                             "pred": "34 of 0, 15 of 1",
#                                             "side": "left",
#                                             "name": "DEFWS <= 0.0",
#                                             "type": "numerical",
#                                             "size": 49.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "pred": "241 of 0, 114 of 1",
#                     "side": "left",
#                     "name": "PIE <= 14.25",
#                     "type": "numerical",
#                     "size": 355.0,
#                     "children": [
#                         {
#                             "pred": "193 of 0, 40 of 1",
#                             "side": "right",
#                             "name": "Team Conference Rank > 6.5",
#                             "type": "numerical",
#                             "size": 233.0,
#                             "children": [
#                                 {
#                                     "pred": "38 of 0, 27 of 1",
#                                     "side": "right",
#                                     "name": "PTS > 21.55",
#                                     "type": "numerical",
#                                     "size": 65.0,
#                                     "children": [
#                                         {
#                                             "pred": "3 of 0, 12 of 1",
#                                             "side": "right",
#                                             "name": "Prior ASG Appearances > 1.5",
#                                             "type": "numerical",
#                                             "size": 15.0
#                                         },
#                                         {
#                                             "pred": "35 of 0, 15 of 1",
#                                             "side": "left",
#                                             "name": "Prior ASG Appearances <= 1.5",
#                                             "type": "numerical",
#                                             "size": 50.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "155 of 0, 13 of 1",
#                                     "side": "left",
#                                     "name": "PTS <= 21.55",
#                                     "type": "numerical",
#                                     "size": 168.0,
#                                     "children": [
#                                         {
#                                             "pred": "3 of 0, 3 of 1",
#                                             "side": "right",
#                                             "name": "AST > 8.65",
#                                             "type": "numerical",
#                                             "size": 6.0
#                                         },
#                                         {
#                                             "pred": "152 of 0, 10 of 1",
#                                             "side": "left",
#                                             "name": "AST <= 8.65",
#                                             "type": "numerical",
#                                             "size": 162.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "48 of 0, 74 of 1",
#                             "side": "left",
#                             "name": "Team Conference Rank <= 6.5",
#                             "type": "numerical",
#                             "size": 122.0,
#                             "children": [
#                                 {
#                                     "pred": "28 of 0, 67 of 1",
#                                     "side": "right",
#                                     "name": "PIE > 11.5",
#                                     "type": "numerical",
#                                     "size": 95.0,
#                                     "children": [
#                                         {
#                                             "pred": "21 of 0, 65 of 1",
#                                             "side": "right",
#                                             "name": "W > 13.5",
#                                             "type": "numerical",
#                                             "size": 86.0
#                                         },
#                                         {
#                                             "pred": "7 of 0, 2 of 1",
#                                             "side": "left",
#                                             "name": "W <= 13.5",
#                                             "type": "numerical",
#                                             "size": 9.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "20 of 0, 7 of 1",
#                                     "side": "left",
#                                     "name": "PIE <= 11.5",
#                                     "type": "numerical",
#                                     "size": 27.0,
#                                     "children": [
#                                         {
#                                             "pred": "2 of 0, 7 of 1",
#                                             "side": "right",
#                                             "name": "PTS > 20.55",
#                                             "type": "numerical",
#                                             "size": 9.0
#                                         },
#                                         {
#                                             "pred": "18 of 0, 0 of 1",
#                                             "side": "left",
#                                             "name": "PTS <= 20.55",
#                                             "type": "numerical",
#                                             "size": 18.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "pred": "8723 of 0, 150 of 1",
#             "side": "left",
#             "name": "PTS <= 18.45",
#             "type": "numerical",
#             "size": 8873.0,
#             "children": [
#                 {
#                     "pred": "559 of 0, 103 of 1",
#                     "side": "right",
#                     "name": "PIE > 12.95",
#                     "type": "numerical",
#                     "size": 662.0,
#                     "children": [
#                         {
#                             "pred": "113 of 0, 74 of 1",
#                             "side": "right",
#                             "name": "Prior ASG Appearances > 0.5",
#                             "type": "numerical",
#                             "size": 187.0,
#                             "children": [
#                                 {
#                                     "pred": "20 of 0, 33 of 1",
#                                     "side": "right",
#                                     "name": "PTS > 16.55",
#                                     "type": "numerical",
#                                     "size": 53.0,
#                                     "children": [
#                                         {
#                                             "pred": "11 of 0, 3 of 1",
#                                             "side": "right",
#                                             "name": "Team Conference Rank > 7.5",
#                                             "type": "numerical",
#                                             "size": 14.0
#                                         },
#                                         {
#                                             "pred": "9 of 0, 30 of 1",
#                                             "side": "left",
#                                             "name": "Team Conference Rank <= 7.5",
#                                             "type": "numerical",
#                                             "size": 39.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "93 of 0, 41 of 1",
#                                     "side": "left",
#                                     "name": "PTS <= 16.55",
#                                     "type": "numerical",
#                                     "size": 134.0,
#                                     "children": [
#                                         {
#                                             "pred": "6 of 0, 13 of 1",
#                                             "side": "right",
#                                             "name": "AST > 8.5",
#                                             "type": "numerical",
#                                             "size": 19.0
#                                         },
#                                         {
#                                             "pred": "87 of 0, 28 of 1",
#                                             "side": "left",
#                                             "name": "AST <= 8.5",
#                                             "type": "numerical",
#                                             "size": 115.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "446 of 0, 29 of 1",
#                             "side": "left",
#                             "name": "Prior ASG Appearances <= 0.5",
#                             "type": "numerical",
#                             "size": 475.0,
#                             "children": [
#                                 {
#                                     "pred": "44 of 0, 17 of 1",
#                                     "side": "right",
#                                     "name": "W > 24.5",
#                                     "type": "numerical",
#                                     "size": 61.0,
#                                     "children": [
#                                         {
#                                             "pred": "3 of 0, 7 of 1",
#                                             "side": "right",
#                                             "name": "PTS > 16.45",
#                                             "type": "numerical",
#                                             "size": 10.0
#                                         },
#                                         {
#                                             "pred": "41 of 0, 10 of 1",
#                                             "side": "left",
#                                             "name": "PTS <= 16.45",
#                                             "type": "numerical",
#                                             "size": 51.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "402 of 0, 12 of 1",
#                                     "side": "left",
#                                     "name": "W <= 24.5",
#                                     "type": "numerical",
#                                     "size": 414.0,
#                                     "children": [
#                                         {
#                                             "pred": "5 of 0, 4 of 1",
#                                             "side": "right",
#                                             "name": "DEFWS > 0.01",
#                                             "type": "numerical",
#                                             "size": 9.0
#                                         },
#                                         {
#                                             "pred": "397 of 0, 8 of 1",
#                                             "side": "left",
#                                             "name": "DEFWS <= 0.01",
#                                             "type": "numerical",
#                                             "size": 405.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 },
#                 {
#                     "pred": "8164 of 0, 47 of 1",
#                     "side": "left",
#                     "name": "PIE <= 12.95",
#                     "type": "numerical",
#                     "size": 8211.0,
#                     "children": [
#                         {
#                             "pred": "263 of 0, 24 of 1",
#                             "side": "right",
#                             "name": "PTS > 16.05",
#                             "type": "numerical",
#                             "size": 287.0,
#                             "children": [
#                                 {
#                                     "pred": "19 of 0, 12 of 1",
#                                     "side": "right",
#                                     "name": "DEFWS > 0.0",
#                                     "type": "numerical",
#                                     "size": 31.0,
#                                     "children": [
#                                         {
#                                             "pred": "5 of 0, 12 of 1",
#                                             "side": "right",
#                                             "name": "PIE > 11.55",
#                                             "type": "numerical",
#                                             "size": 17.0
#                                         },
#                                         {
#                                             "pred": "14 of 0, 0 of 1",
#                                             "side": "left",
#                                             "name": "PIE <= 11.55",
#                                             "type": "numerical",
#                                             "size": 14.0
#                                         }
#                                     ]
#                                 },
#                                 {
#                                     "pred": "244 of 0, 12 of 1",
#                                     "side": "left",
#                                     "name": "DEFWS <= 0.0",
#                                     "type": "numerical",
#                                     "size": 256.0,
#                                     "children": [
#                                         {
#                                             "pred": "1 of 0, 2 of 1",
#                                             "side": "right",
#                                             "name": "STL > 2.3",
#                                             "type": "numerical",
#                                             "size": 3.0
#                                         },
#                                         {
#                                             "pred": "243 of 0, 10 of 1",
#                                             "side": "left",
#                                             "name": "STL <= 2.3",
#                                             "type": "numerical",
#                                             "size": 253.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         },
#                         {
#                             "pred": "7901 of 0, 23 of 1",
#                             "side": "left",
#                             "name": "PTS <= 16.05",
#                             "type": "numerical",
#                             "size": 7924.0,
#                             "children": [
#                                 {
#                                     "pred": "0 of 0, 1 of 1",
#                                     "side": "right",
#                                     "name": "TOV > 5.05",
#                                     "type": "numerical",
#                                     "size": 1.0
#                                 },
#                                 {
#                                     "pred": "7901 of 0, 22 of 1",
#                                     "side": "left",
#                                     "name": "TOV <= 5.05",
#                                     "type": "numerical",
#                                     "size": 7923.0,
#                                     "children": [
#                                         {
#                                             "pred": "36 of 0, 5 of 1",
#                                             "side": "right",
#                                             "name": "Prior ASG Appearances > 8.5",
#                                             "type": "numerical",
#                                             "size": 41.0
#                                         },
#                                         {
#                                             "pred": "7865 of 0, 17 of 1",
#                                             "side": "left",
#                                             "name": "Prior ASG Appearances <= 8.5",
#                                             "type": "numerical",
#                                             "size": 7882.0
#                                         }
#                                     ]
#                                 }
#                             ]
#                         }
#                     ]
#                 }
#             ]
#         }
#     ]
# }
